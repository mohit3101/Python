# %% [markdown]
# # Task : Session 1
# ### Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!
#
# ## Q1 :- Print the given strings as per stated format.

# %%
# Write your code here
words=["Data", "Science", "Mentorship", "Program", "By", "CampusX"]
'-'.join(words)
# Out:
# 'Data-Science-Mentorship-Program-By-CampusX'

# %% [markdown]
# ## Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
c=float(input('Enter the value of celsius: '))

f=1.8*c+32
print(f'Celsius: {c}°C       Fahrenheit value: {f}°F')
# Out:
# Enter the value of celsius: 39.6
# Celsius: 39.6°C       Fahrenheit value: 103.28°F

# %% [markdown]
# ## Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
a=int(input('Enter the 1st number:'))
b=int(input('Enter the 2nd number:'))

print(f'1st number: {a}')
print(f'2nd number: {b}')
a,b=b,a

print('---Swapped Numbers--------')
print(f'1st number: {a}')
print(f'2nd number: {b}')
# Out:
# Enter the 1st number:14
# Enter the 2nd number:23
# 1st number: 14
# 2nd number: 23
# ---Swapped Numbers--------
# 1st number: 23
# 2nd number: 14

# %% [markdown]
# ## Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
x1=float(input('Enter the x-coordinate of 1st point:'))
y1=float(input('Enter the y-coordinate of 1st point:'))
x2=float(input('Enter the x-coordinate of 2nd point:'))
y2=float(input('Enter the y-coordinate of 2nd point:'))

d=((x1-x2)**2 + (y1-y2)**2)**0.5

print(f'Euclidean distance between two coordinates: {round(d,2)}')
# Out:
# Enter the x-coordinate of 1st point:4
# Enter the y-coordinate of 1st point:5
# Enter the x-coordinate of 2nd point:2
# Enter the y-coordinate of 2nd point:9
# Euclidean distance between two coordinates: 4.47

# %%
def distance(ax,ay,bx,by):
    return round(((ax-bx)**2+(ay-by)**2)**0.5,2)

# %%
distance(4,5,2,9)
# Out:
# 4.47

# %% [markdown]
# ## Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
p=1000
r=0.08
t=5

si=p*r*t

print(f'Simple Interest: Rs {si}')
# Out:
# Simple Interest: Rs 400.0

# %% [markdown]
# ## Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
# For example: Input: heads -> 4 legs -> 12
# Output: dogs -> 2 chicken -> 2

# %%
h=int(input('Input: heads '))
l=int(input('Input: legs '))


#c+d=h
#c+2*d=l/2

d=l/2-h
c=2*h-l/2

print(f'dogs->{d} chicken->{c}')
# Out:
# Input: heads 4
# Input: legs 12
# dogs->2.0 chicken->2.0

# %% [markdown]
# ## Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user

# %%
n=int(input('Enter the number: '))
s=n*(n+1)*(2*n+1)/6

print(f'The sum of squares of first {n} natural numbers: {s}')
# Out:
# Enter the number: 3
# The sum of squares of first 3 natural numbers: 14.0

# %%
def sum_natural(n):
    return n*(n+1)*(2*n+1)/6

sum_natural(3)
# Out:
# 14.0

# %% [markdown]
# ## Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
a1=int(input('Please enter the value of a1: '))
a2=int(input('Please enter the value of a2: '))
n=int(input('Please enter the value of n: '))

d=a2-a1

an=a1+(n-1)*d

print(f'Value of nth term: {an}')
# Out:
# Please enter the value of a1: 1
# Please enter the value of a2: 8
# Please enter the value of n: 10
# Value of nth term: 64

# %% [markdown]
# ## Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
import math
n1= int(input("Enter numerator of first fraction: "))
d1= int(input("Enter denominator of first fraction: "))
n2= int(input("Enter numerator of second fraction: "))
d2= int(input("Enter denominator of second fraction: "))

gcd=math.gcd(d1,d2)

lcm=math.lcm(d1,d2)

sum_num=n1*d2+n2*d1
sum_den=d1*d2

simplified_num = sum_num // gcd
simplified_den = sum_den // gcd

print(f"The sum of {n1}/{d1} and {n2}/{d2} is {simplified_num}/{simplified_den}")
# Out:
# Enter numerator of first fraction: 1
# Enter denominator of first fraction: 2
# Enter numerator of second fraction: 1
# Enter denominator of second fraction: 3
# The sum of 1/2 and 1/3 is 5/6

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
# Input:
# Dimensions of the milk tank
# H = 20cm, L = 20cm, B = 20cm
#
# Dimensions of the glass
# h = 3cm, r = 1cm

# %%
h1 = 20
l1 = 20
b1= 20


h2 = 3
r2 = 1

v1=h1*l1*b1
v2=3.14*(r2**2)*h2

n=round(v1/v2)
n
# Out:
# 849
