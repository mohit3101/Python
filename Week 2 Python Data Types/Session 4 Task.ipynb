# %% [markdown]
# ### `Problem 1:` Combine two lists index-wise(columns wise)
#
# Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
#
# `Given List:`
# ```
# list1 = ["M", "na", "i", "Kh"]
# list2 = ["y", "me", "s", "an"]
# ```
#
# `Output:`
# ```
# [['M','y'], ['na', me'], ['i', 's'], ['Kh', 'an']]
# ```

# %%
list1 = ["M", "na", "i", "Kh"]
list2 = ["y", "me", "s", "an"]

[[i,j] for i,j in zip(list1,list2)]
# Out:
# [['M', 'y'], ['na', 'me'], ['i', 's'], ['Kh', 'an']]

# %% [markdown]
# ### `Problem 2:` Add new item to list after a specified item
# Write a program to add item 7000 after 6000 in the following Python List
# ```
# list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
# ```
# `Output:`
# ```
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]
# ```

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

list1[2][2].append(7000)
list1
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# ### `Problem 3:` Update no of items available
#
# Suppose you are given a list of candy and another list of same size representing no of items of respective candy.
#
# i.e -
# ```
# candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# no_of_items = [10,20,34,74,32]
# ```
#
# Write a program to show no. of items of each candy type.
#
# `Output:`
#
# ```
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32
#
# ```

# %%
candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]

for k in ([i+'-'+str(j) for i,j in zip(candy_list,no_of_items)]):
    print(k)
# Out:
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32

# %%
candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]

lst=[[i,str(j)] for i,j in zip(candy_list,no_of_items)]
lst

for i in lst:
    print('-'.join(i))
# Out:
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32

# %% [markdown]
# ### `Problem 4:` Running Sum on list
# Write a program to print a list after performing running sum on it.
#
# i.e:
#
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,3,6,10,15,21]
# ```

# %%
lst = [1,2,3,4,5,6]

temp=[]
temp_sum=0
for i in lst:
    temp_sum=temp_sum+i
    temp.append(temp_sum)
temp
# Out:
# [1, 3, 6, 10, 15, 21]

# %% [markdown]
# ### `Problem 5:` You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.
#
# i.e. Say given list is `[2,4,6,10,1]`
# resultant list will be `[22,20,10,23]`.
#
# For 1st element `2` ->> these are greater `(4+6+10)` values and `2` itself so on adding becomes `22`.
#
# For 2nd element `4` ->> greater elements are `(6, 10)` and `4` itself, so on adding `20`
#
# like wise for all other elememts.
#
# `[2,4,6,10,1]`-->`[22,20,16,10,23]`

# %%
lst=[2,4,6,10,1]
result=[]

for i in lst:
    temp_sum=i
    for j in lst:
        if i<j:
            temp_sum=temp_sum+j
    result.append(temp_sum)
result
# Out:
# [22, 20, 16, 10, 23]

# %%
lst=[2,4,6,10,1]
result=[]

for i in lst:
    temp_lst=lst.copy() #---use a copy here
    temp_lst.remove(i)
    temp=[]
    for j in temp_lst:
        if j>i:
            temp.append(j)
    result.append(i+sum(temp))
result
# Out:
# [22, 20, 16, 10, 23]

# %% [markdown]
# ### `Problem 6:` Find list of common unique items from two list. and show in increasing order
#
# `Input`
#
# ```
# num1 = [23,45,67,78,89,34]
# num2 = [34,89,55,56,39,67]
# ```
#
# `Output:`
# ```
# [34, 67, 89]
# ```

# %%
num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]

sorted(set(num1).intersection(set(num2)))
# Out:
# [34, 67, 89]

# %% [markdown]
# ### `Problem 7:` Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.
#
# `Input:`
# ```
# ['1ac21', '23fg', '456', '098d','1','kls']
# ```
#
# `Output:`
# ```
# ['456', '23fg', '1ac21', '1', 'kls', '098d']
#
# ```

# %%
lst=['1ac21', '23fg', '456', '098d','1','kls']
product=[]
for i in lst:
    temp_product=1
    for j in i:
        if j.isdigit():
            temp_product=temp_product*int(j)
    product.append(temp_product)    
            
temp=list(zip(lst,product))

def sort_second(val):
    return val[1]

temp.sort(key=sort_second, reverse=True)
[print(temp)]
[i[0] for i in temp]
# Out:
# [('456', 120), ('23fg', 6), ('1ac21', 2), ('1', 1), ('kls', 1), ('098d', 0)]
# ['456', '23fg', '1ac21', '1', 'kls', '098d']

# %%
lst=['1ac21', '23fg', '456', '098d','1','kls']
result=[]
for i in lst:
    j_product=1
    for j in i:
        if j.isdigit():
            j_product=j_product*int(j)
    result.append((i,j_product))

result

def sortSecond(val):
    return val[1]
result.sort(key=sortSecond,reverse=True)

print(result)


[i[0] for i in result]
# Out:
# [('456', 120), ('23fg', 6), ('1ac21', 2), ('1', 1), ('kls', 1), ('098d', 0)]
# ['456', '23fg', '1ac21', '1', 'kls', '098d']

# %% [markdown]
# `Problem 8:` Split String of list on K character.
#
# **Example :**
#
# Input:
# ```bash
# ['CampusX is a channel', 'for data-science', 'aspirants.']
# ```
#
# Output:
# ```bash
# ['CampusX', 'is', 'a', 'channel', 'for', 'data-science', 'aspirants.']
# ```

# %%
lst=['CampusX is a channel', 'for data-science', 'aspirants.']
inp='a'
' '.join(lst).split(inp)
# Out:
# ['C', 'mpusX is ', ' ch', 'nnel for d', 't', '-science ', 'spir', 'nts.']

# %% [markdown]
# ### `Problem 9:` Convert Character Matrix to single String using string comprehension.
#
# **Example 1:**
#
# Input:
# ```bash
# [['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]
# ```
#
# Output:
# ```bash
# campux is best channel
# ```

# %%
lst=[['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]
result=[]
for i in lst:
    result.append(''.join(i))
' '.join(result)
# Out:
# 'campux is best channel'

# %%
lst=[['c', 'a', 'm', 'p', 'u', 'x'], ['i', 's'], ['b', 'e', 's', 't'], ['c', 'h', 'a', 'n', 'n', 'e', 'l']]

sent=[]
for i in lst:
    sent.append(''.join(i))
print(' '.join(sent))
# Out:
# campux is best channel

# %% [markdown]
# ### `Problem 10:` Add Space between Potential Words.
#
# **Example:**
#
# Input:
#
# ```bash
# ['campusxIs', 'bestFor', 'dataScientist']
# ```
#
# Output:
# ```bash
# ['campusx Is', 'best For', 'data Scientist']
# ```

# %%
inp=['campusxIs', 'bestFor', 'dataScientist']

''.join('campusx Is')

for i in inp:
    
    for j in i:
        if j.isupper():
# Out:
# 'campusx Is'

# %%
inp=['campusxIs', 'bestFor', 'dataScientist']
result=[]

for i in inp:
    temp=[]
    for j in i:
        new_elements=[]
        if j.islower():
            new_elements.append(j)
        elif j.isupper():
            new_elements.append(str(' '+j))
        print(new_elements)
        temp.append(new_elements)
    print(temp)
    result.append(''.join(new_elements))
print(result)    
list('campusxIs')
# Out:
# ['c']
# ['a']
# ['m']
# ['p']
# ['u']
# ['s']
# ['x']
# [' I']
# ['s']
# [['c'], ['a'], ['m'], ['p'], ['u'], ['s'], ['x'], [' I'], ['s']]
# ['b']
# ['e']
# ['s']
# ['t']
# [' F']
# ['o']
# ['r']
# [['b'], ['e'], ['s'], ['t'], [' F'], ['o'], ['r']]
# ['d']
# ['a']
# ['t']
# ['a']
# [' S']
# ['c']
# ['i']
# ['e']
# ['n']
# ['t']
# ['i']
# ['s']
# ['t']
# [['d'], ['a'], ['t'], ['a'], [' S'], ['c'], ['i'], ['e'], ['n'], ['t'], ['i'], ['s'], ['t']]
# ['s', 'r', 't']
# ['c', 'a', 'm', 'p', 'u', 's', 'x', 'I', 's']

# %%
inp=['campusxIs', 'bestFor', 'dataScientist']

result=[]
for i in inp:
    for j in i:
        if j.isupper():
            temp=j
            print(j)
            i=i.split(temp)
    result.append(i)
result
# Out:
# I
# F
# S
# [['campusx', 's'], ['best', 'or'], ['data', 'cientist']]

# %% [markdown]
# ### `Problem 11:` Write a program that can perform union operation on 2 lists
#
# **Example:**
#
# Input:
#
# ```bash
# [1,2,3,4,5,1]
# [2,3,5,7,8]
# ```
#
# Output:
# ```bash
# [1,2,3,4,5,7,8]
# ```

# %%
l1=[1,2,3,4,5,1]
l2=[2,3,5,7,8]
l1.extend(l2)
sorted(list(set(l1)))
# Out:
# [1, 2, 3, 4, 5, 7, 8]

# %% [markdown]
# ### `Problem 12:` Write a program that can find the max number of each row of a matrix
#
# **Example:**
#
# Input:
#
# ```bash
# [[1,2,3],[4,5,6],[7,8,9]]
# ```
#
# Output:
# ```bash
# [3,6,9]
# ```

# %%
lst=[[1,2,3],[4,5,6],[7,8,9]]
temp=[]
for i in lst:
    temp.append(max(i))
temp
# Out:
# [3, 6, 9]

# %% [markdown]
# ### `Problem 13:` Write a list comprehension to print the following matrix
#
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
[[i,i+1,i+2] for i in range(0,7,3)]
# Out:
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %% [markdown]
# ### `Problem 14:` Write a list comprehension that can transpose a given matrix
#
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# [1, 4, 7]<br>
# [2, 5, 8]<br>
# [3, 6, 9]<br>

# %%
matrix = [
[1,2,3,'a'],
[4,5,6,'b'],
[7,8,9,'c']
]


result=[]

for i in range(len(matrix)+1):
#     print(matrix[i])
    temp=[]
    for j in matrix:
        temp.append(j[i])
    result.append(temp)

#     print(matrix[i][j])
result
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9], ['a', 'b', 'c']]

# %%
# Write code here
matrix = [
[1,2,3,'a'],
[4,5,6,'b'],
[7,8,9,'c']
]

[[row[i] for row in matrix]for i in range(len(matrix))]
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
matrix = [
[1,2,3,'a'],
[4,5,6,'b'],
[7,8,9,'c']
]
transposed_matrix = [[matrix[j][i] for j in range(len(matrix))] for i in range(len(matrix[0]))]
print(transposed_matrix)
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9], ['a', 'b', 'c']]

# %% [markdown]
# ### `Problem 15:` Write a list comprehension that can flatten a nested list
#
# Input<br>
# matrix = [<br>
#   [1,2,3],<br>
#           [4,5,6],<br>
#           [7,8,9]<br>]<br>
#
# Output:<br>
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
matrix = [
[1,2,3],
[4,5,6],
[7,8,9]
]
temp=[]

for i in matrix:
    for j in i:
        temp.append(j)
temp
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
[j for i in matrix for j in i]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
